# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel("/content/colab_data.xlsx")
data.shape
# Out:
# (40, 8)

# %%
data.head()
# Out:
#        YEAR  ALMONDS   HAZELNUTS      PECANS     WALNUTS  MACADAMIAS  \
# 0   1980/81    147.0  143.993506  168.266701  126.403199  159.363684
# 1   1981/82     78.0   97.483162  123.324851  126.967628  174.551092
# 2   1982/83     94.0   85.420453  143.554729  131.778112  162.667361
# 3   1983/84    104.0   81.825334  129.212759   88.946984  144.618456
# 4   1984/85     77.4   88.184786  133.445990  116.366466  152.319919
#
#    PISTACHIOS         ALL
# 0  472.350230  151.461898
# 1  335.637846   99.871443
# 2  386.010363  118.010029
# 3  334.916865  107.303534
# 4  223.854665   94.992710

# %%
data=data.dropna()

# %%
data.describe
# Out:
# <bound method NDFrame.describe of           YEAR  ALMONDS   HAZELNUTS      PECANS     WALNUTS  MACADAMIAS  \
# 0      1980/81    147.0  143.993506  168.266701  126.403199  159.363684
# 1      1981/82     78.0   97.483162  123.324851  126.967628  174.551092
# 2      1982/83     94.0   85.420453  143.554729  131.778112  162.667361
# 3      1983/84    104.0   81.825334  129.212759   88.946984  144.618456
# 4      1984/85     77.4   88.184786  133.445990  116.366466  152.319919
# 5      1985/86     80.0   87.231603  149.866255  104.722592  159.586177
# 6      1986/87    192.0   95.564657  156.764879  137.970708  176.095091
# 7      1987/88    100.0  116.078370  114.836663  119.562319  184.899846
# 8     1988/89     105.0  107.217908  123.422964  111.810842  198.106978
# 9     1989/90     102.0  102.538462  175.547852  125.215000  195.905789
# 10    1990/91      93.0  109.485622  253.859562  130.575221  180.497469
# 11    1991/92     119.0   93.219430  260.250542  130.462621  154.083205
# ...

# %%
data.columns
# Out:
# Index(['YEAR', 'ALMONDS', 'HAZELNUTS', 'PECANS', 'WALNUTS', 'MACADAMIAS',
#        'PISTACHIOS', 'ALL'],
#       dtype='object')

# %%
cor1=data.corr(method = 'pearson')

# %%
sns.heatmap(cor1,annot=True)
# Out:
# <Axes: >

# %%
cor=data.corr(method = 'spearman',min_periods=2)

# %%
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %%
cor2=data.corr(method = 'kendall',min_periods=)
sns.heatmap(cor2,annot=True)
# Out:
# <Axes: >

# %%
# correlation between ALMOND and MACADAMIAS


plt.scatter(data['HAZELNUTS'],data['PECANS'])
plt.xlabel("HAZELNUTS")
plt.ylabel("PECANS")
plt.show()
