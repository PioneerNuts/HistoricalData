# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("/content/colab_data.xlsx")

# %%
data.head()
# Out:
#        YEAR  ALMONDS   HAZELNUTS      PECANS     WALNUTS  MACADAMIAS  \
# 0   1980/81    147.0  143.993506  168.266701  126.403199  159.363684
# 1   1981/82     78.0   97.483162  123.324851  126.967628  174.551092
# 2   1982/83     94.0   85.420453  143.554729  131.778112  162.667361
# 3   1983/84    104.0   81.825334  129.212759   88.946984  144.618456
# 4   1984/85     77.4   88.184786  133.445990  116.366466  152.319919
#
#    PISTACHIOS         ALL  Inflation rate  Adjusted Value of $1  \
# 0  472.350230  151.461898            13.5                  3.20
# 1  335.637846   99.871443            10.3                  2.97
# 2  386.010363  118.010029             6.2                  2.60
# 3  334.916865  107.303534             3.2                  2.43
# 4  223.854665   94.992710             4.3                  2.32
#
#    Inflation \nadjusted values \nFor Walnuts  \
# 0                                 404.490237
# 1                                 377.093856
# ...

# %%
d = data.drop(['ALMONDS', 'HAZELNUTS', 'PECANS', 'WALNUTS', 'MACADAMIAS', 'PISTACHIOS', 'ALL', 'Inflation rate', 'Adjusted Value of $1'], axis =1)
d.head()
# Out:
#        YEAR  Inflation \nadjusted values \nFor Walnuts  \
# 0   1980/81                                 404.490237
# 1   1981/82                                 377.093856
# 2   1982/83                                 342.623092
# 3   1983/84                                 216.141172
# 4   1984/85                                 269.970201
#
#    Inflation\nAdjusted\nValues \nFor MACADAMIAS  \
# 0                                    509.963790
# 1                                    518.416744
# 2                                    422.935139
# 3                                    351.422849
# 4                                    353.382211
#
#    Inflation \nAdjusted \nValues\nFor Almonds  \
# 0                                     470.400
# 1                                     231.660
# 2                                     244.400
# 3                                     252.720
# 4                                     179.568
#
#    Inflation \nAdjusted\nValues\nFor Pistachios  \
# ...

# %%
corr = d.corr()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >
